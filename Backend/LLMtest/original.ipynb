# %% [markdown]
# ### 초안 작성 예시

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자 기업분석 보고서 초안 작성해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 물론입니다. 삼성전자 기업분석 보고서를 작성하기 위한 초안을 제공하겠습니다. 이 초안은 일반적인 구조와 내용을 포함하고 있으며, 이후 세부적인 데이터를 추가하여 완성할 수 있습니다.
#
# ---
#
# # 삼성전자 기업분석 보고서
#
# ## 1. 회사 개요
# - **회사명:** 삼성전자 주식회사
# - **설립연도:** 1969년
# - **본사 소재지:** 대한민국 경기도 수원시
# - **대표이사:** [현재 대표이사 이름 삽입]
# - **사업 분야:** 전자, 정보통신, 반도체, 디스플레이, 가전 등
#
# ## 2. 산업분석
# - **산업 동향:** 글로벌 전자 및 반도체 시장의 성장, 5G 및 AI 기술 발전에 따른 수요 증가
# - **시장 점유율:** 주요 제품군에서의 세계 점유율 현황 (예: 스마트폰, 메모리 반도체 등)
# - **경쟁사:** 애플, 인텔, TSMC, 소니 등
#
# ## 3. 재무 분석
# - **매출액:** 최근 3년간 매출 규모 및 성장률
# - **영업이익:** 영업이익률 및 주요 제품군별 이익 기여도
# - **주요 재무 비율:** 부채비율, 자본수익률, 이익률 등
#
# ## 4. 사업부문 분석
# - **반도체 부문:** 메모리와 비메모리 반도체 시장에서의 위치 및 전략
# - **IM(IT & Mobile) 부문:** 스마트폰 시장 점유율 및 신제품 출시 전략
# - **CE(Consumer Electronics) 부문:** TV 및 가전제품 시장 동향
# - **디스플레이 부문:** OLED, QLED 등 최신 기술 동향 및 시장 점유율
#
# ## 5. SWOT 분석
# - **강점 (Strengths):** 글로벌 브랜드 인지도, 기술력, 광범위한 제품 포트폴리오
# - **약점 (Weaknesses):** 특정 사업부문 의존도, 가격 경쟁에 따른 마진 압박
# - **기회 (Opportunities):** 5G, IoT, AI 시장 성장, 신흥시장 확대
# ...

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자 2027년 기업분석 보고서 초안 작성해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 삼성전자 2027년 기업분석 보고서 초안
#
# **서론**
#
# 2027년 현재, 삼성전자는 여전히 글로벌 기술 산업에서 주도적인 위치를 차지하고 있습니다. 이 보고서는 삼성전자의 최근 성과, 시장 위치, 주요 사업 부문, 재무 상태, 혁신 전략, 그리고 미래 전망을 분석합니다.
#
# **1. 기업 개요**
#
# 삼성전자는 1969년에 설립되어 반도체, 디스플레이, 모바일, 가전제품 등 다양한 분야에서 세계적인 리더로 자리매김하고 있습니다. 본사는 대한민국에 위치하고 있으며, 글로벌 시장에서 광범위한 고객 기반을 확보하고 있습니다.
#
# **2. 시장 위치 및 경쟁력**
#
# - **반도체 부문**: 삼성전자는 여전히 메모리 반도체 시장에서 세계 1위 자리를 유지하고 있으며, 비메모리 반도체 시장에서도 영향력을 확대하고 있습니다. 첨단 공정 기술과 대규모 생산 능력을 통해 경쟁력을 유지하고 있습니다.
#
# - **모바일 부문**: 스마트폰 시장에서의 삼성의 지위는 꾸준하며, 특히 프리미엄 라인업과 폴더블 디바이스에서 혁신을 지속하고 있습니다. 글로벌 시장에서 애플, 중국 제조사들과의 경쟁이 치열하지만, 삼성의 브랜드 신뢰성과 폭넓은 제품 포트폴리오가 강점입니다.
#
# - **가전 부문**: AI와 IoT 기술을 접목한 스마트 가전 제품을 지속적으로 출시하며, 소비자 가전 시장에서의 입지를 강화하고 있습니다.
#
# **3. 재무 상태**
#
# 삼성전자의 2027년 재무 상태는 안정적이며, 최근 5년간 지속적인 매출 성장세를 이어가고 있습니다. 반도체 부문의 호황과 더불어 다양한 사업 부문에서의 균형 잡힌 성장이 재무 실적을 뒷받침합니다. 영업이익 및 순이익 또한 개선되고 있으며, 주주들에게 배당금 지급을 꾸준히 유지하고 있습니다.
#
# **4. 혁신 및 기술 개발**
#
# ...

# %% [markdown]
# ### 단락 생성

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자 기업분석해서 단락생성 해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 삼성전자는 한국을 대표하는 글로벌 전자회사로, 반도체, 모바일, 가전제품 등의 분야에서 세계적인 리더십을 자랑합니다. 1969년에 설립되어 꾸준히 성장해온 삼성전자는 현재 반도체 매출에서 세계 1위를 차지하고 있으며, 메모리 반도체뿐만 아니라 파운드리 사업에서도 영향력을 확대하고 있습니다. 스마트폰 시장에서는 갤럭시 시리즈를 통해 애플, 화웨이 등과 경쟁하며 혁신적인 기술과 디자인을 선보이고 있습니다. 또한 TV, 냉장고, 세탁기 등 다양한 가전제품에서도 최신 기술과 사용자 편의성을 강화하여 시장을 선도하고 있습니다. 삼성전자는 연구개발(R&D)에 대한 지속적인 투자와 글로벌 생산 네트워크를 통해 제품 경쟁력을 유지하고 있으며, 인공지능(AI), 사물인터넷(IoT), 5G와 같은 미래 기술에서도 적극적으로 대응하고 있습니다. 이러한 노력들은 삼성전자가 글로벌 시장에서의 입지를 더욱 확고히 다지는 데 기여하고 있습니다.

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자가 만드는 미사일에 대해 단락생성 해줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 삼성전자는 주로 전자제품과 반도체 부문에서 세계적인 명성을 얻고 있지만, 군수산업 분야에서는 직접적으로 무기를 제작하지는 않습니다. 대신, 삼성테크윈(현 한화테크윈)과 같은 계열사를 통해 방위산업에 간접적으로 참여한 적이 있습니다. 이러한 계열사들은 미사일 시스템과 관련된 고도의 기술을 개발하거나, 군사용 전자장비 등을 생산하는 데 기여했습니다. 한국의 국방 산업은 여러 기업들이 협력하여 발전시키고 있으며, 삼성의 기술력은 이를 뒷받침하는 중요한 요소 중 하나입니다. 현재 방위산업은 한화그룹이 주요 역할을 맡고 있으며, 삼성전자는 주로 상업 부문에 집중하고 있습니다.

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "SK네트웍스 "}
    ]
)
print(completion.choices[0].message.content)
# Out:
# SK네트웍스는 SK 그룹의 계열사 중 하나로, 다양한 사업 분야에서 활동하는 한국의 종합 상사입니다. 주요 사업 분야로는 정보통신, 에너지, 자동차, 패션 등이 있으며, 국내외에서 다양한 제품과 서비스를 제공하고 있습니다. 또한, SK네트웍스는 지속 가능한 경영과 사회적 책임을 강조하며, 다양한 사회 공헌 활동을 전개하고 있습니다. 회사의 최신 동향이나 재무 성과에 대한 구체적인 정보는 SK네트웍스의 공식 웹사이트나 금융 보고서를 참고하시기 바랍니다.

# %% [markdown]
# # 요약 / 확장

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자는 한국을 대표하는 글로벌 전자회사로, 반도체, 모바일, 가전제품 등의 분야에서 세계적인 리더십을 자랑합니다. 1969년에 설립되어 꾸준히 성장해온 삼성전자는 현재 반도체 매출에서 세계 1위를 차지하고 있으며, 메모리 반도체뿐만 아니라 파운드리 사업에서도 영향력을 확대하고 있습니다. 스마트폰 시장에서는 갤럭시 시리즈를 통해 애플, 화웨이 등과 경쟁하며 혁신적인 기술과 디자인을 선보이고 있습니다. 또한 TV, 냉장고, 세탁기 등 다양한 가전제품에서도 최신 기술과 사용자 편의성을 강화하여 시장을 선도하고 있습니다. 삼성전자는 연구개발(R&D)에 대한 지속적인 투자와 글로벌 생산 네트워크를 통해 제품 경쟁력을 유지하고 있으며, 인공지능(AI), 사물인터넷(IoT), 5G와 같은 미래 기술에서도 적극적으로 대응하고 있습니다. 이러한 노력들은 삼성전자가 글로벌 시장에서의 입지를 더욱 확고히 다지는 데 기여하고 있습니다. 요약해줘"}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 삼성전자는 한국을 대표하는 글로벌 전자회사로, 1969년 설립 이래 반도체, 모바일, 가전제품 분야에서 세계적인 리더십을 자랑합니다. 반도체 매출 세계 1위를 기록하며, 메모리와 파운드리 사업에서 강력한 영향을 미치고 있습니다. 스마트폰 시장에서는 갤럭시 시리즈로 애플, 화웨이와 경쟁하며 혁신을 선도하고 있으며, TV, 냉장고, 세탁기 등의 가전제품에서도 최신 기술과 사용자 편의성을 강화하여 시장을 이끌고 있습니다. 삼성전자는 지속적인 연구개발 투자와 글로벌 생산 네트워크를 통해 경쟁력을 유지하고 있으며, 인공지능, 사물인터넷, 5G와 같은 미래 기술에도 적극 대응하고 있습니다. 이러한 노력은 삼성전자가 글로벌 시장에서의 입지를 더욱 강화하는 데 기여하고 있습니다.

# %% [markdown]
# ### 데이터 시각화 (Web)

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자의 최근 3개년 주가 그래프 그려줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 죄송하지만, 실시간 주가 정보나 특정 주식의 최신 가격 변동을 그래프로 제공할 수는 없습니다. 하지만 최근 삼성전자의 주가 그래프를 확인하고 싶다면, 다음과 같은 방법을 사용할 수 있습니다:
#
# 1. **금융 웹사이트**: 네이버 금융, 다음 금융, 야후 파이낸스 또는 Investing.com과 같은 웹사이트에서는 삼성전자의 역사적인 주가 데이터를 확인할 수 있습니다.
#
# 2. **증권사 앱**: 사용중인 증권사 앱을 통해 삼성전자의 주가 데이터를 조회할 수 있습니다.
#
# 3. **데이터 분석 툴**: Python의 Pandas와 Matplotlib 등을 사용하여 금융API (예: Yahoo Finance API)를 통해 데이터를 가져와 직접 그래프를 그릴 수 있습니다.
#
# 이를 통해 삼성전자의 주가를 직접 확인하고 분석할 수 있습니다.

# %%
from openai import OpenAI
import os
# dotenv
from dotenv import load_dotenv
load_dotenv()

client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY")
)
completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": "삼성전자의 2027년 주가 그래프 그려줘."}
    ]
)
print(completion.choices[0].message.content)
# Out:
# 죄송하지만, 저는 미래의 특정 주가를 예측하거나 그래프를 그릴 수 없습니다. 주식 시장의 가격은 매우 변동성이 크고 여러 요인에 의해 영향을 받기 때문에, 정확한 예측은 불가능합니다. 투자 결정을 내리기 전에 금융 전문가와 상담하거나 철저한 조사를 하는 것이 좋습니다.

# %% [markdown]
# ### 데이터 시각화(csv)

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

# CSV 파일 읽기 (파일 경로에 맞게 수정하세요)
data = pd.read_csv("2024 삼성전자 주가.csv")
csv_string = data.to_csv(index=False)

# OpenAI 클라이언트 초기화
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# CSV 데이터를 포함한 질문 메시지 생성
message_content = f"자료를 다양하게 분석해서 그래프로 그려줘. 아래는 CSV 데이터입니다:\n{csv_string}"

completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": message_content}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 분석 결과를 그래프로 표시하기 위해 Python의 matplotlib와 pandas 라이브러리를 사용할 수 있습니다. 다음 스크립트는 주어진 CSV 데이터를 읽고 날짜에 따른 주식 가격 변화를 시각적으로 나타냅니다.
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # 데이터 문자열을 pandas DataFrame으로 변환
# data = """
# Date,005930
# 2024-01-02,77916.609375
# 2024-01-03,75371.59375
# 2024-01-04,74980.0546875
# 2024-01-05,74980.0546875
# 2024-01-08,74882.171875
# 2024-01-09,73120.2265625
# 2024-01-10,72043.5
# 2024-01-11,71651.9609375
# 2024-01-12,71554.0625
# 2024-01-15,72337.15625
# 2024-01-16,71064.640625
# 2024-01-17,69498.4765625
# 2024-01-18,70183.6875
# 2024-01-19,73120.2265625
# 2024-01-22,73511.7734375
# 2024-01-23,73609.6640625
# 2024-01-24,72435.0390625
# 2024-01-25,72532.921875
# 2024-01-26,71847.734375
# 2024-01-29,72826.5703125
# 2024-01-30,72728.6875
# 2024-01-31,71162.53125
# 2024-02-01,72043.5
# 2024-02-02,73609.6640625
# 2024-02-05,72728.6875
# 2024-02-06,72826.5703125
# 2024-02-07,73413.890625
# 2024-02-08,72532.921875
# ...

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

# CSV 파일 읽기 (파일 경로에 맞게 수정하세요)
data = pd.read_csv("2024 삼성전자 주가.csv")
csv_string = data.to_csv(index=False)

# OpenAI 클라이언트 초기화
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# CSV 데이터를 포함한 질문 메시지 생성
message_content = f"자료에서 2023년 정보를 분석해서 그려줘. 아래는 CSV 데이터입니다:\n{csv_string}"

completion = client.chat.completions.create(
    model="gpt-4o",
    store=True,
    messages=[
        {"role": "user", "content": message_content}
    ]
)

print(completion.choices[0].message.content)
# Out:
# 현재 데이터에서 2023년의 정보는 없고, 2024년의 정보로만 이루어져 있는 것으로 보입니다. 그러나 2024년 데이터를 분석하여 시각화할 수 있습니다. 제공된 데이터는 주식 가격에 대한 것으로 보이며, 이를 시각화하기 위해 시계열 그래프를 그릴 수 있습니다.
#
# Python의 `matplotlib`와 `pandas` 라이브러리를 사용하여 시각화할 수 있습니다. 다음은 이 데이터를 시계열 그래프로 그리는 방법입니다:
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # 주어진 CSV 데이터를 pandas 데이터프레임으로 로드
# data = {
#     'Date': ['2024-01-02', '2024-01-03', '2024-01-04', '2024-01-05', '2024-01-08',
#              '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12', '2024-01-15',
#              # ... 데이터는 계속됩니다 ...
#              '2024-12-24', '2024-12-26', '2024-12-27', '2024-12-30'],
#     '005930': [77916.609375, 75371.59375, 74980.0546875, 74980.0546875, 74882.171875,
#                73120.2265625, 72043.5, 71651.9609375, 71554.0625, 72337.15625,
#                # ... 데이터는 계속됩니다 ...
#                54031.58203125, 53237.0, 53700.0, 53200.0]
# }
#
# # 데이터프레임 생성
# df = pd.DataFrame(data)
#
# # `Date` 열을 datetime 형식으로 변환
# ...
